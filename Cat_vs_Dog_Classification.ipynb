# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tongpython/cat-and-dog")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'cat-and-dog' dataset.
# Path to dataset files: /kaggle/input/cat-and-dog

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten,BatchNormalization,Dropout

# %%
data_augmentation = keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.1),
        tf.keras.layers.RandomZoom(0.1),
    ]
)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    directory='/kaggle/input/cat-and-dog/training_set/training_set',
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(256, 256)
)

validation_ds = tf.keras.utils.image_dataset_from_directory(
    directory='/kaggle/input/cat-and-dog/test_set/test_set',
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(256, 256)
)
# Out:
# Found 8005 files belonging to 2 classes.
# Found 2023 files belonging to 2 classes.

# %%
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %% [markdown]
# ### Normalize Data

# %%
def process(image, label):
    image = tf.cast(image/255. ,tf.float32)
    return image, label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %% [markdown]
# ### Create a CNN Model

# %%
from keras.regularizers import l2

model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3), kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu', kernel_regularizer=l2(0.01)))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(128,activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 254, 254, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 125, 125, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 30, 30, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    14,745,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,193 (56.64 MB)
#  Trainable params: 14,847,745 (56.64 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0001)

history = model.fit(train_ds, epochs=50, validation_data=validation_ds, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 511ms/step - accuracy: 0.7273 - loss: 1.4833 - val_accuracy: 0.6975 - val_loss: 1.1291 - learning_rate: 0.0010
# Epoch 2/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 510ms/step - accuracy: 0.7481 - loss: 1.0469 - val_accuracy: 0.7113 - val_loss: 1.0685 - learning_rate: 0.0010
# Epoch 3/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 511ms/step - accuracy: 0.7368 - loss: 1.1067 - val_accuracy: 0.7039 - val_loss: 1.0881 - learning_rate: 0.0010
# Epoch 4/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 141s 510ms/step - accuracy: 0.7490 - loss: 0.9744 - val_accuracy: 0.6441 - val_loss: 1.2722 - learning_rate: 0.0010
# Epoch 5/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 510ms/step - accuracy: 0.7523 - loss: 1.0243 - val_accuracy: 0.6826 - val_loss: 1.0263 - learning_rate: 0.0010
# Epoch 6/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 512ms/step - accuracy: 0.7398 - loss: 0.9993 - val_accuracy: 0.6930 - val_loss: 1.0047 - learning_rate: 0.0010
# Epoch 7/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 512ms/step - accuracy: 0.7341 - loss: 0.9797 - val_accuracy: 0.7316 - val_loss: 0.9864 - learning_rate: 0.0010
# Epoch 8/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 513ms/step - accuracy: 0.7497 - loss: 0.9403 - val_accuracy: 0.6970 - val_loss: 1.0189 - learning_rate: 0.0010
# Epoch 9/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 514ms/step - accuracy: 0.7461 - loss: 0.8895 - val_accuracy: 0.7311 - val_loss: 0.9023 - learning_rate: 0.0010
# Epoch 10/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 513ms/step - accuracy: 0.7527 - loss: 0.8740 - val_accuracy: 0.7360 - val_loss: 0.8790 - learning_rate: 0.0010
# Epoch 11/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 131s 523ms/step - accuracy: 0.7508 - loss: 0.8644 - val_accuracy: 0.7237 - val_loss: 1.0227 - learning_rate: 0.0010
# Epoch 12/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 510ms/step - accuracy: 0.7550 - loss: 0.8877 - val_accuracy: 0.7222 - val_loss: 0.9940 - learning_rate: 0.0010
# Epoch 13/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 127s 507ms/step - accuracy: 0.7603 - loss: 0.8830 - val_accuracy: 0.5853 - val_loss: 1.1903 - learning_rate: 0.0010
# Epoch 14/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 509ms/step - accuracy: 0.7800 - loss: 0.7580 - val_accuracy: 0.7870 - val_loss: 0.6533 - learning_rate: 2.0000e-04
# Epoch 15/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 130s 516ms/step - accuracy: 0.8099 - loss: 0.5985 - val_accuracy: 0.7954 - val_loss: 0.6243 - learning_rate: 2.0000e-04
# Epoch 16/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 140s 507ms/step - accuracy: 0.8305 - loss: 0.5584 - val_accuracy: 0.7380 - val_loss: 0.7801 - learning_rate: 2.0000e-04
# Epoch 17/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 508ms/step - accuracy: 0.8374 - loss: 0.5377 - val_accuracy: 0.8156 - val_loss: 0.5559 - learning_rate: 2.0000e-04
# Epoch 18/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 511ms/step - accuracy: 0.8403 - loss: 0.5298 - val_accuracy: 0.8171 - val_loss: 0.5939 - learning_rate: 2.0000e-04
# Epoch 19/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 515ms/step - accuracy: 0.8307 - loss: 0.5449 - val_accuracy: 0.8344 - val_loss: 0.5433 - learning_rate: 2.0000e-04
# Epoch 20/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 512ms/step - accuracy: 0.8469 - loss: 0.5163 - val_accuracy: 0.8166 - val_loss: 0.5910 - learning_rate: 2.0000e-04
# Epoch 21/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 515ms/step - accuracy: 0.8556 - loss: 0.5087 - val_accuracy: 0.8206 - val_loss: 0.5948 - learning_rate: 2.0000e-04
# Epoch 22/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 513ms/step - accuracy: 0.8566 - loss: 0.5152 - val_accuracy: 0.8576 - val_loss: 0.5215 - learning_rate: 2.0000e-04
# Epoch 23/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 131s 519ms/step - accuracy: 0.8585 - loss: 0.5185 - val_accuracy: 0.8285 - val_loss: 0.5855 - learning_rate: 2.0000e-04
# Epoch 24/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 511ms/step - accuracy: 0.8703 - loss: 0.5071 - val_accuracy: 0.8591 - val_loss: 0.5402 - learning_rate: 2.0000e-04
# Epoch 25/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 509ms/step - accuracy: 0.8709 - loss: 0.5137 - val_accuracy: 0.8646 - val_loss: 0.5038 - learning_rate: 2.0000e-04
# Epoch 26/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 512ms/step - accuracy: 0.8647 - loss: 0.5169 - val_accuracy: 0.8245 - val_loss: 0.6221 - learning_rate: 2.0000e-04
# Epoch 27/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 130s 519ms/step - accuracy: 0.8797 - loss: 0.5003 - val_accuracy: 0.8581 - val_loss: 0.5349 - learning_rate: 2.0000e-04
# Epoch 28/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 509ms/step - accuracy: 0.8758 - loss: 0.4850 - val_accuracy: 0.8631 - val_loss: 0.5201 - learning_rate: 2.0000e-04
# Epoch 29/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 511ms/step - accuracy: 0.8879 - loss: 0.4675 - val_accuracy: 0.8784 - val_loss: 0.4695 - learning_rate: 1.0000e-04
# Epoch 30/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 127s 507ms/step - accuracy: 0.9047 - loss: 0.4195 - val_accuracy: 0.8833 - val_loss: 0.4467 - learning_rate: 1.0000e-04
# Epoch 31/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 508ms/step - accuracy: 0.9051 - loss: 0.4056 - val_accuracy: 0.8710 - val_loss: 0.4803 - learning_rate: 1.0000e-04
# Epoch 32/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 127s 507ms/step - accuracy: 0.9045 - loss: 0.4044 - val_accuracy: 0.8903 - val_loss: 0.4276 - learning_rate: 1.0000e-04
# Epoch 33/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 128s 510ms/step - accuracy: 0.9079 - loss: 0.3834 - val_accuracy: 0.8809 - val_loss: 0.4500 - learning_rate: 1.0000e-04
# Epoch 34/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 514ms/step - accuracy: 0.9090 - loss: 0.3908 - val_accuracy: 0.8883 - val_loss: 0.4327 - learning_rate: 1.0000e-04
# Epoch 35/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 131s 522ms/step - accuracy: 0.9156 - loss: 0.3732 - val_accuracy: 0.8665 - val_loss: 0.4921 - learning_rate: 1.0000e-04
# Epoch 36/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 513ms/step - accuracy: 0.9156 - loss: 0.3726 - val_accuracy: 0.8710 - val_loss: 0.5053 - learning_rate: 1.0000e-04
# Epoch 37/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 130s 517ms/step - accuracy: 0.9122 - loss: 0.3769 - val_accuracy: 0.9011 - val_loss: 0.4161 - learning_rate: 1.0000e-04
# Epoch 38/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 140s 512ms/step - accuracy: 0.9170 - loss: 0.3654 - val_accuracy: 0.8987 - val_loss: 0.4042 - learning_rate: 1.0000e-04
# Epoch 39/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 129s 515ms/step - accuracy: 0.9159 - loss: 0.3766 - val_accuracy: 0.8898 - val_loss: 0.4377 - learning_rate: 1.0000e-04
# Epoch 40/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 130s 519ms/step - accuracy: 0.9155 - loss: 0.3648 - val_accuracy: 0.8992 - val_loss: 0.4164 - learning_rate: 1.0000e-04
# Epoch 41/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 140s 511ms/step - accuracy: 0.9201 - loss: 0.3614 - val_accuracy: 0.9001 - val_loss: 0.4111 - learning_rate: 1.0000e-04
# Epoch 42/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 131s 519ms/step - accuracy: 0.9233 - loss: 0.3509 - val_accuracy: 0.8937 - val_loss: 0.4240 - learning_rate: 1.0000e-04
# Epoch 43/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 140s 510ms/step - accuracy: 0.9169 - loss: 0.3605 - val_accuracy: 0.8754 - val_loss: 0.4785 - learning_rate: 1.0000e-04

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()
